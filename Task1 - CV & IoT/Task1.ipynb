# %% [markdown]
# # The Sparks Foundation - Computer Vision and Internet of Things
# ### (Task from different Domain)
# ## GRIP August 21
# ## Task - 1
#
# # Submitted By - Sanket Mathur

# %% [markdown]
# # Importing Libraries

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # Setting up File locations and Checking sample images

# %%
# setting the path and the labels list for classification of targets on the basis in human understandable form

# execued from kaggle kernel
train_dir = os.path.join('/kaggle/input/garbage-classification/Garbage classification/Garbage classification') 
labels = ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']

# %%
# checking the size of data available to us for training out model

for label in labels:
    directory = os.path.join(train_dir, label)
    print("Images of label \"" + label + "\":\t", len(os.listdir(directory)))
# Out:
# Images of label "cardboard":	 403
# Images of label "glass":	 501
# Images of label "metal":	 410
# Images of label "paper":	 594
# Images of label "plastic":	 482
# Images of label "trash":	 137

# %%
# plotting images of different review for understanding the dataset

plt.figure(figsize=(30,14))

for i in range(6):
    directory = os.path.join(train_dir, labels[i])
    for j in range(10):
        path = os.path.join(directory, os.listdir(directory)[j])
        img = mpimg.imread(path)
        
        plt.subplot(6, 10, i*10 + j + 1)
        plt.imshow(img)
        
        if j == 0:
            plt.ylabel(labels[i], fontsize=20)
        
plt.setp(plt.gcf().get_axes(), xticks=[], yticks=[]);
plt.tight_layout()
plt.show()

# %%
# checking size of individual image

directory = os.path.join(train_dir, 'cardboard')
path = os.path.join(directory, os.listdir(directory)[0])
image = mpimg.imread(path)
image.shape
# Out:
# (384, 512, 3)

# %% [markdown]
# # Deep Learning

# %%
# creating the model

model = tf.keras.Sequential([
  tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(384, 512, 3)),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.MaxPooling2D(2, 2),
  tf.keras.layers.Dropout(0.2),
    
  tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.MaxPooling2D(2, 2),
  tf.keras.layers.Dropout(0.2),
    
  tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.MaxPooling2D(2, 2),
  tf.keras.layers.Dropout(0.2),

  tf.keras.layers.Conv2D(256, (3, 3), activation='relu'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Conv2D(256, (3, 3), activation='relu'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.MaxPooling2D(2, 2),
  tf.keras.layers.Dropout(0.2),
    
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Dropout(0.4),
  tf.keras.layers.Dense(6, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 382, 510, 32)      896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 382, 510, 32)      128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 380, 508, 32)      9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 380, 508, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 190, 254, 32)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 190, 254, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 188, 252, 64)      18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 188, 252, 64)      256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 186, 250, 64)      36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 186, 250, 64)      256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 93, 125, 64)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 93, 125, 64)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 91, 123, 128)      73856
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 91, 123, 128)      512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 89, 121, 128)      147584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 89, 121, 128)      512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 44, 60, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 44, 60, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 42, 58, 256)       295168
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 42, 58, 256)       1024
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 40, 56, 256)       590080
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 40, 56, 256)       1024
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 20, 28, 256)       0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 20, 28, 256)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 143360)            0
# _________________________________________________________________
# dense (Dense)                (None, 512)               73400832
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 3078
# =================================================================
# Total params: 74,582,054
# Trainable params: 74,579,110
# Non-trainable params: 2,944
# _________________________________________________________________

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer=keras.optimizers.Adam(lr = 0.0001), metrics=['accuracy'])

# %%
# creating generators for combining data and increasing the gainable insights by slightly modifying the images in the dataset

train_datagen = ImageDataGenerator(horizontal_flip=True,vertical_flip=True,
                                   rotation_range=15,zoom_range=0.1,
                                   width_shift_range=0.15,height_shift_range=0.15,
                                   shear_range=0.1,
                                   fill_mode="nearest",
                                   rescale=1./255., 
                                   validation_split=0.2)

train_generator = train_datagen.flow_from_directory(train_dir, target_size=(384, 512), batch_size=32, class_mode='binary', subset='training')
validation_generator = train_datagen.flow_from_directory(train_dir, target_size=(384, 512), batch_size=32, class_mode='binary', subset='validation')
# Out:
# Found 2024 images belonging to 6 classes.
# Found 503 images belonging to 6 classes.

# %%
# creating the callback function so that it can be used to end the training in case reached a good accuracy rate (above 90%)

class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('accuracy')>0.90):
            print("\nReached 90% accuracy so cancelling training!")
            self.model.stop_training = True

callbacks = myCallback()

# %%
history = model.fit(train_generator, epochs=50, verbose=1, validation_data=validation_generator, callbacks=[callbacks])
# Out:
# Epoch 1/50
# 64/64 [==============================] - 219s 3s/step - loss: 2.0317 - accuracy: 0.4187 - val_loss: 9.6915 - val_accuracy: 0.1571
# Epoch 2/50
# 64/64 [==============================] - 184s 3s/step - loss: 1.2865 - accuracy: 0.5566 - val_loss: 22.0667 - val_accuracy: 0.1590
# Epoch 3/50
# 64/64 [==============================] - 184s 3s/step - loss: 1.2229 - accuracy: 0.5659 - val_loss: 30.3908 - val_accuracy: 0.1590
# Epoch 4/50
# 64/64 [==============================] - 184s 3s/step - loss: 1.1905 - accuracy: 0.5559 - val_loss: 31.5925 - val_accuracy: 0.1590
# Epoch 5/50
# 64/64 [==============================] - 183s 3s/step - loss: 1.0934 - accuracy: 0.6113 - val_loss: 42.5652 - val_accuracy: 0.1650
# Epoch 6/50
# 64/64 [==============================] - 184s 3s/step - loss: 1.0273 - accuracy: 0.6469 - val_loss: 4.2160 - val_accuracy: 0.2068
# Epoch 7/50
# 64/64 [==============================] - 184s 3s/step - loss: 1.0822 - accuracy: 0.6379 - val_loss: 2.4834 - val_accuracy: 0.2545
# Epoch 8/50
# 64/64 [==============================] - 183s 3s/step - loss: 1.0518 - accuracy: 0.6337 - val_loss: 5.9844 - val_accuracy: 0.3678
# Epoch 9/50
# 64/64 [==============================] - 184s 3s/step - loss: 0.9777 - accuracy: 0.6651 - val_loss: 2.8401 - val_accuracy: 0.3519
# Epoch 10/50
# 64/64 [==============================] - 183s 3s/step - loss: 0.9087 - accuracy: 0.6732 - val_loss: 2.7378 - val_accuracy: 0.4155
# Epoch 11/50
# 64/64 [==============================] - 183s 3s/step - loss: 0.9060 - accuracy: 0.6814 - val_loss: 2.6245 - val_accuracy: 0.4215
# Epoch 12/50
# 64/64 [==============================] - 184s 3s/step - loss: 0.9825 - accuracy: 0.6774 - val_loss: 3.0610 - val_accuracy: 0.4195
# Epoch 13/50
# 64/64 [==============================] - 183s 3s/step - loss: 0.8608 - accuracy: 0.6910 - val_loss: 3.3767 - val_accuracy: 0.4095
# Epoch 14/50
# 64/64 [==============================] - 184s 3s/step - loss: 0.8142 - accuracy: 0.7110 - val_loss: 1.9048 - val_accuracy: 0.4592
# Epoch 15/50
# 64/64 [==============================] - 184s 3s/step - loss: 0.7837 - accuracy: 0.7490 - val_loss: 2.4060 - val_accuracy: 0.4115
# Epoch 16/50
# 64/64 [==============================] - 183s 3s/step - loss: 0.7365 - accuracy: 0.7454 - val_loss: 2.7821 - val_accuracy: 0.3917
# Epoch 17/50
# 64/64 [==============================] - 184s 3s/step - loss: 0.7326 - accuracy: 0.7456 - val_loss: 1.5930 - val_accuracy: 0.5427
# Epoch 18/50
# 64/64 [==============================] - 184s 3s/step - loss: 0.7201 - accuracy: 0.7420 - val_loss: 1.7753 - val_accuracy: 0.5249
# Epoch 19/50
# 64/64 [==============================] - 184s 3s/step - loss: 0.7187 - accuracy: 0.7502 - val_loss: 1.8066 - val_accuracy: 0.4672
# Epoch 20/50
# 64/64 [==============================] - 183s 3s/step - loss: 0.9422 - accuracy: 0.6720 - val_loss: 1.6134 - val_accuracy: 0.4950
# Epoch 21/50
# 64/64 [==============================] - 184s 3s/step - loss: 0.7437 - accuracy: 0.7476 - val_loss: 1.7418 - val_accuracy: 0.4930
# Epoch 22/50
# 64/64 [==============================] - 184s 3s/step - loss: 0.7004 - accuracy: 0.7523 - val_loss: 1.8481 - val_accuracy: 0.4354
# Epoch 23/50
# 64/64 [==============================] - 184s 3s/step - loss: 0.6557 - accuracy: 0.7739 - val_loss: 1.8721 - val_accuracy: 0.4672
# Epoch 24/50
# 64/64 [==============================] - 185s 3s/step - loss: 0.6729 - accuracy: 0.7516 - val_loss: 1.6735 - val_accuracy: 0.5249
# Epoch 25/50
# 64/64 [==============================] - 184s 3s/step - loss: 0.6063 - accuracy: 0.7855 - val_loss: 1.7361 - val_accuracy: 0.4930
# Epoch 26/50
# 64/64 [==============================] - 184s 3s/step - loss: 0.5966 - accuracy: 0.7819 - val_loss: 1.5466 - val_accuracy: 0.5229
# Epoch 27/50
# 64/64 [==============================] - 184s 3s/step - loss: 0.6361 - accuracy: 0.7857 - val_loss: 1.7490 - val_accuracy: 0.5089
# Epoch 28/50
# 64/64 [==============================] - 184s 3s/step - loss: 0.6374 - accuracy: 0.7748 - val_loss: 1.3877 - val_accuracy: 0.5586
# Epoch 29/50
# 64/64 [==============================] - 184s 3s/step - loss: 0.5406 - accuracy: 0.8017 - val_loss: 1.6518 - val_accuracy: 0.5189
# Epoch 30/50
# 64/64 [==============================] - 184s 3s/step - loss: 0.5271 - accuracy: 0.8167 - val_loss: 1.6565 - val_accuracy: 0.5089
# Epoch 31/50
# 64/64 [==============================] - 184s 3s/step - loss: 0.5203 - accuracy: 0.8195 - val_loss: 1.6890 - val_accuracy: 0.4831
# Epoch 32/50
# 64/64 [==============================] - 183s 3s/step - loss: 0.4851 - accuracy: 0.8245 - val_loss: 1.5716 - val_accuracy: 0.5189
# Epoch 33/50
# 64/64 [==============================] - 184s 3s/step - loss: 0.5543 - accuracy: 0.8092 - val_loss: 1.6321 - val_accuracy: 0.5268
# Epoch 34/50
# 64/64 [==============================] - 184s 3s/step - loss: 0.5659 - accuracy: 0.8066 - val_loss: 1.4016 - val_accuracy: 0.5865
# Epoch 35/50
# 64/64 [==============================] - 183s 3s/step - loss: 0.4484 - accuracy: 0.8486 - val_loss: 1.1512 - val_accuracy: 0.6282
# Epoch 36/50
# 64/64 [==============================] - 184s 3s/step - loss: 0.5549 - accuracy: 0.8037 - val_loss: 1.2603 - val_accuracy: 0.6103
# Epoch 37/50
# 64/64 [==============================] - 184s 3s/step - loss: 0.4292 - accuracy: 0.8589 - val_loss: 1.8780 - val_accuracy: 0.4911
# Epoch 38/50
# 64/64 [==============================] - 184s 3s/step - loss: 0.4924 - accuracy: 0.8111 - val_loss: 1.4232 - val_accuracy: 0.5746
# Epoch 39/50
# 64/64 [==============================] - 184s 3s/step - loss: 0.4156 - accuracy: 0.8626 - val_loss: 2.0980 - val_accuracy: 0.4453
# Epoch 40/50
# 64/64 [==============================] - 183s 3s/step - loss: 0.4217 - accuracy: 0.8527 - val_loss: 3.8357 - val_accuracy: 0.3638
# Epoch 41/50
# 64/64 [==============================] - 184s 3s/step - loss: 0.5185 - accuracy: 0.8243 - val_loss: 1.2687 - val_accuracy: 0.5885
# Epoch 42/50
# 64/64 [==============================] - 184s 3s/step - loss: 0.4542 - accuracy: 0.8331 - val_loss: 1.2210 - val_accuracy: 0.6243
# Epoch 43/50
# 64/64 [==============================] - 184s 3s/step - loss: 0.4503 - accuracy: 0.8385 - val_loss: 2.1570 - val_accuracy: 0.4215
# Epoch 44/50
# 64/64 [==============================] - 184s 3s/step - loss: 0.5077 - accuracy: 0.8182 - val_loss: 2.0238 - val_accuracy: 0.4732
# Epoch 45/50
# 64/64 [==============================] - 183s 3s/step - loss: 0.4502 - accuracy: 0.8450 - val_loss: 1.6514 - val_accuracy: 0.5089
# Epoch 46/50
# 64/64 [==============================] - 184s 3s/step - loss: 0.3931 - accuracy: 0.8688 - val_loss: 1.9938 - val_accuracy: 0.4911
# Epoch 47/50
# 64/64 [==============================] - 184s 3s/step - loss: 0.4107 - accuracy: 0.8329 - val_loss: 1.3273 - val_accuracy: 0.5845
# Epoch 48/50
# 64/64 [==============================] - 184s 3s/step - loss: 0.6295 - accuracy: 0.7865 - val_loss: 1.9600 - val_accuracy: 0.5149
# Epoch 49/50
# 64/64 [==============================] - 184s 3s/step - loss: 0.6429 - accuracy: 0.7758 - val_loss: 1.3100 - val_accuracy: 0.6004
# Epoch 50/50
# 64/64 [==============================] - 184s 3s/step - loss: 0.4902 - accuracy: 0.8326 - val_loss: 1.8124 - val_accuracy: 0.4990

# %%
cat = int(input('Enter any category by index: '))
ind = int(input('Enter any index to test: '))

directory = os.path.join(train_dir, labels[cat % 6])
try:
    path = os.path.join(directory, os.listdir(directory)[ind])
    img = mpimg.imread(path)
    x = keras.preprocessing.image.img_to_array(img)
    x = np.expand_dims(x, axis=0)

    images = np.vstack([x])
    classes = model.predict(images)
    pred = labels[np.argmax(classes)]
    
    plt.imshow(img)
    plt.xticks([])
    plt.yticks([])
    plt.title('Actual: {}      Pred: {}'.format(labels[cat], pred))
    
except:
    print('Invalid Value')
# Out:
# Enter any category by index:  0
# Enter any index to test:  10
